# %%
import pandas as pd
import numpy as np
from utils.mpip_parse import MPIPParser
from utils.parse_coscheduling_runs import CoSchedulingRunsParser
import matplotlib.pyplot as plt

# %%
parser = CoSchedulingRunsParser()
data_isolated = parser.parse_isolated("../run_data/experiments_coscheduling_isolated/20260527_083005/data", progress=True)
# Out:
# Phase 1: Collecting files: 64it [00:00, 16025.04it/s]
# Phase 2: Parsing files: 100%|██████████| 64/64 [00:19<00:00,  3.36it/s]

# %%
data_isolated
# Out:
#          App  Num Nodes  Run Iteration  App Time Average  MPI Time Average  \
# 0   tricount          1              0        282.000000         50.169643
# 1     fiesta          1              2        298.785714         39.040714
# 2     laghos          8              0        331.000000         54.542634
# 3   tricount          8              0        371.000000        196.979911
# 4     lammps          8              1        350.000000         13.770692
# ..       ...        ...            ...               ...               ...
# 59  minivite          1              2        444.000000         27.933929
# 60    minife          8              3        389.000000         14.035112
# 61  tricount          1              2        280.000000         49.603571
# 62  minivite          1              1        441.000000         28.240893
# 63  minivite          1              3        439.000000         26.208929
#
#     Total Messages Sent   Total Bytes
# 0                243320  2.510000e+12
# 1                 67200  1.706000e+11
# 2             801311390  6.337223e+11
# 3               7120960  1.020000e+13
# 4                457408  6.704208e+11
# ..                  ...           ...
# 59               747720  1.437801e+11
# 60              6788000  3.822487e+11
# 61               243320  2.510000e+12
# 62               747720  1.437801e+11
# 63               747720  1.437801e+11
#
# [64 rows x 7 columns]
